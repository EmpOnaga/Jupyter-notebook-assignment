# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Becze Anca__
# Senior researcher

# %% [markdown]
# _I am interested in data science because I need to upgrade my income situation and I need to better use my knowledge and data that I’ve collected over the years._

# %% [markdown]
# ### Cell 5 is supose to say "You've got this....." and a name

# %%
def You_got_this(recipient):
    return 'You got this {}!'.format(recipient)
You_got_this('Anca')

# %% [markdown]
# ![1525780_612785732102463_566447301_n.jpg](attachment:1525780_612785732102463_566447301_n.jpg)
#
# ***
#
#  - I love dim sum
#  - Best time ever
#  - Dim sum delicios
#
#  ***
#
# |Name|Age|Sex|
# |----|---|-----|
# |Anca|37|F|
# |Maria|41|F|
# |Jhon|39|M|
#
#  ***
#
#  [Dim Sum recipes](https://thewoksoflife.com/category/recipes/dim-sum/)
